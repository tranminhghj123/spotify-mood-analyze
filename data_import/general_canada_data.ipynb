# %%
# import library
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from datetime import datetime
import os
from dotenv import load_dotenv
import json
import time
import requests

print(f"succesful importing all librares")
# Out:
# succesful importing all librares

# %% [markdown]
# **II) Data Conecting**

# %%
load_dotenv()

# access to spotify ID
auth_manager = SpotifyClientCredentials(
    client_id=os.getenv('SPOTIFY_CLIENT_ID'),
    client_secret=os.getenv('SPOTIFY_CLIENT_SECRET')
)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# Data extracting

# %%
# get all playist 
def get_playlist():
    """
    Find official hits from 2010 to 2025 

    """

    playlists = {} # list of playlists information from years 

    # collecting the data fronm 2010 to 2025
    for year in range(2010, 2026):
        # searching for keyword
        results = sp.search(q = f'top hits of {year}', type = 'playlist', market = 'CA', limit = 5)

        for playlist in results['playlists']['items']:

            if playlist != None:  
                if f'top hits of {year}' in str(playlist['name']).lower():# key word matched 
                    # add the track for the playlist 
                    playlists[f'top hits of {year}'] ={
                        'year': year,
                        'id': playlist['id'],
                        'name' : playlist['name']
                    }

                    # only one playlist for one year 
                    break 

    

    return playlists


# collecting tracks data from playlist 
def collect_playlist_tracks(playlist_id, playlist_name, playlist_year):
    """
    Collects all tracks from a playlist with detailed information 

    """
    print(f"Collecting tracks form: {playlist_name}")


    results = sp.playlist_tracks(playlist_id= playlist_id, market='CA')

    tracks_data=[]# collection of alll tracks in playlist 

    # accessing to each track in playlist 
    for idx, item in enumerate(results['items'], 1):
        if item['track'] is None:
            continue

        track = item['track']
        
        track_info = { # data form of each track 
            'year' : playlist_year,
            'collection_date': datetime.now().strftime('%Y-%m-%d'),
            'collection_timestamp': datetime.now().isoformat(),
            'playlist_rank': idx,
            'playlist_name': playlist_name,
            'track_id': track['id'],
            'track_name': track['name'],
            'artist_id': track['artists'][0]['id'],
            'artist_name': track['artists'][0]['name'],
            'album_name': track['album']['name'],
            'album_release_date': track['album']['release_date'],
            'duration_ms': track['duration_ms'],
            'popularity': track['popularity'],
            'explicit': track['explicit']
        }
        
        tracks_data.append(track_info)
    
    return tracks_data

# Turning spotify track ids to recoo beat track_id 
def get_track_id_recoobeat(track_ids):

    url = "https://api.reccobeats.com/v1/track?"
    headers = {'Accept': 'application/json'}  # Fixed typo
    batch = 39  # limit return for each request
    all_id = {}

    for i in range(0, len(track_ids), batch):
        spotify_ids = track_ids[i:batch+i]
        params = [('ids', id) for id in spotify_ids]  # end points for spotify_ids

        try:
            response = requests.get(url=url, headers=headers, params=params)

            if response.status_code == 200:
                data = response.json()
                content = data['content']
                
                for j in range(0, len(content)):  # Changed 'i' to 'j'
                    
                    # using spotify_Id as key 
                    all_id[content[j]['href'].split("track/")[1]] = {
                        'id': content[j]['id'],
                        'artists': [a['name'] for a in content[j]['artists']]
                    }
                
            else:
                print(f"Error: {response.status_code}")
                return None 

        except Exception as e:
            print(f'Exception occurred: {e}')
            return None 

    return all_id

### Collecting audio features for each track
def get_audio_features(recoo_beat_id, spotify_id):
    """
    Get audio features for multiple tracks at once
    Audio features include: danceability, energy, key, loudness, mode, 
    speechiness, acousticness, instrumentalness, liveness, valence, tempo
    """
    
    track_features = []
    try :


        url = f"https://api.reccobeats.com/v1/track/{recoo_beat_id}/audio-features"

        payload = {}
        headers = {
        'Accept': 'application/json'
        }

        response = requests.request("GET", url, headers=headers, data=payload)

        if response.status_code ==200:
            data = response.json()

            # add the corresponding spotify ID
            data['spotify_id'] = spotify_id

            track_features.append(data)

            return track_features
        
        else: 
            print(f"Error url request: {response.status_code}")
    except Exception as e:
        print(f"Error occured: {e}")

        return None

# %%
def main():
    """
    Main function for Collecting all the data 
    By running this code, remove all the dataset before and retracking the data 

    """

    print(f"=" * 20)
    print(f"Music trend data colllection")
    print(f'=' * 20)
    print(f"Collection Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print()



    ### PART I
    ### Collecting playlists data 
    print("Finding top hits")
    playlists = get_playlist() # Collecting the playlist for top hits 

    if not playlists: # if nothing match the keywords
        print("Could not find any playlist")
        exit

    
    print()
    print(f"Found {len(playlists)} playlists")

    for key, playlist in playlists.items():
        print(f"{playlist['name']}")

    print('Finishing Collecting all playlists')
    print()



    ### PART II
    ### Collecting tracks from all the playlists 
    print(f'=' *20)
    print("Collecting tracks data")
    print(f'='* 20)
    # all tracks data 
    all_track = []

    for playlist_type, playlist_info in playlists.items():# Accessing to the playlist of each years 

        tracks = collect_playlist_tracks(playlist_info['id'], playlist_info['name'], playlist_info['year'])# playlist detail 
        all_track.extend(tracks)

    print("Finishing collecting all tracks")
    print()
    # Coverting to dataframe
    print(f'Coverting tracks dataset to dataframe')
    tracks_df = pd.DataFrame(all_track)
    print('Finishing coverting to dataframe')
    print()

    ## PART III
    ## Transfering spotifyID to Recoo BeatID 
    print(f'='*20)
    print('Transfering to Recoo Beat')
    print(f'='*20)

    spotify_ids = tracks_df['track_id'].tolist()# list of spotify_id for every track

    recoo_beat_ids = get_track_id_recoobeat(track_ids= spotify_ids)

    ### Part IV
    ### getting audio features 
    print(f'='*20)
    print('Transfering to Recoo Beat')
    print(f'='*20)


    all_features =[]

    for spotify_id in recoo_beat_ids.keys():

        track_feature = get_audio_features(recoo_beat_id= recoo_beat_ids[spotify_id]['id'], spotify_id = spotify_id)

        all_features.extend(track_feature)

        break

    display(all_features)
    display(all_track)


    return None
collecting_data = main()
# Out:
# ====================
# Music trend data colllection
# ====================
# Collection Date: 2025-12-27 13:45:29
#
# Finding top hits
#
# Found 13 playlists
# Top Hits of 2011
# Top Hits of 2012
# Top Hits of 2013
# Top Hits of 2014
# Top Hits of 2015
# Top Hits of 2016
# TOP HITS OF 2017
# Top Hits of 2018
# Top Hits of 2020
# Top Hits of 2021
# Top Hits of 2022
# Top Hits of 2023
# Top Hits of 2024
# Finishing Collecting all playlists
#
# ====================
# Collecting tracks data
# ====================
# Collecting tracks form: Top Hits of 2011
# Collecting tracks form: Top Hits of 2012
# Collecting tracks form: Top Hits of 2013
# Collecting tracks form: Top Hits of 2014
# Collecting tracks form: Top Hits of 2015
# Collecting tracks form: Top Hits of 2016
# Collecting tracks form: TOP HITS OF 2017
# Collecting tracks form: Top Hits of 2018
# Collecting tracks form: Top Hits of 2020
# Collecting tracks form: Top Hits of 2021
# Collecting tracks form: Top Hits of 2022
# Collecting tracks form: Top Hits of 2023
# Collecting tracks form: Top Hits of 2024
# Finishing collecting all tracks
#
# Coverting tracks dataset to dataframe
# Finishing coverting to dataframe
#
# ====================
# Transfering to Recoo Beat
# ====================
# ====================
# Transfering to Recoo Beat
# ====================
# [{'id': '3da929a8-c402-43a4-9ed3-69765d6ddf9c',
#   'href': 'https://open.spotify.com/track/2U8g9wVcUu9wsg6i7sFSv8',
#   'isrc': 'GBAYE1101193',
#   'acousticness': 0.00194,
#   'danceability': 0.425,
#   'energy': 0.732,
#   'instrumentalness': 0.0103,
#   'key': 9,
#   'liveness': 0.171,
#   'loudness': -6.883,
#   'mode': 1,
#   'speechiness': 0.0396,
#   'tempo': 117.98,
#   'valence': 0.333,
#   'spotify_id': '2U8g9wVcUu9wsg6i7sFSv8'}]
# [{'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202860',
#   'playlist_rank': 1,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7Igq29CgfVTTxdGpGT7BP7',
#   'track_name': 'Price Tag',
#   'artist_id': '2gsggkzM5R49q6jpPvazou',
#   'artist_name': 'Jessie J',
#   'album_name': 'Who You Are',
#   'album_release_date': '2011-01-01',
#   'duration_ms': 222533,
#   'popularity': 23,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202877',
#   'playlist_rank': 2,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '20zQZVyUNPbq8kZACdgYrh',
#   'track_name': 'On The Floor',
#   'artist_id': '2DlGxzQSjYe5N6G9nkYghR',
#   'artist_name': 'Jennifer Lopez',
#   'album_name': 'LOVE?',
#   'album_release_date': '2011-04-29',
#   'duration_ms': 284866,
#   'popularity': 63,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202888',
#   'playlist_rank': 3,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '4wCmqSrbyCgxEXROQE6vtV',
#   'track_name': 'Somebody That I Used To Know',
#   'artist_id': '2AsusXITU8P25dlRNhcAbG',
#   'artist_name': 'Gotye',
#   'album_name': 'Making Mirrors',
#   'album_release_date': '2011-01-01',
#   'duration_ms': 244973,
#   'popularity': 77,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202897',
#   'playlist_rank': 4,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1tAutlhI9FwnKn7fVgmd5P',
#   'track_name': 'Without You (feat. Usher)',
#   'artist_id': '1Cs0zKBU1kc0i8ypK3B9ai',
#   'artist_name': 'David Guetta',
#   'album_name': 'Nothing but the Beat',
#   'album_release_date': '2011-08-30',
#   'duration_ms': 208133,
#   'popularity': 30,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202905',
#   'playlist_rank': 5,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6lanRgr6wXibZr8KgzXxBl',
#   'track_name': 'a thousand years',
#   'artist_id': '7H55rcKCfwqkyDFH9wpKM6',
#   'artist_name': 'Christina Perri',
#   'album_name': 'a thousand years',
#   'album_release_date': '2011-10-18',
#   'duration_ms': 285120,
#   'popularity': 85,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202914',
#   'playlist_rank': 6,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6qn9YLKt13AGvpq9jfO8py',
#   'track_name': 'We Found Love',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H',
#   'artist_name': 'Rihanna',
#   'album_name': 'Talk That Talk',
#   'album_release_date': '2011-11-18',
#   'duration_ms': 215226,
#   'popularity': 85,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202923',
#   'playlist_rank': 7,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5yDL13y5giogKs2fSNf7sj',
#   'track_name': 'Glad You Came',
#   'artist_id': '2NhdGz9EDv2FeUw6udu2g1',
#   'artist_name': 'The Wanted',
#   'album_name': 'Battleground (Deluxe Edition)',
#   'album_release_date': '2011-01-01',
#   'duration_ms': 197935,
#   'popularity': 77,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202931',
#   'playlist_rank': 8,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0tUVnDB0pM7xYGGgIKnyVf',
#   'track_name': 'Super Bass',
#   'artist_id': '0hCNtLu0JehylgoiP8L4Gh',
#   'artist_name': 'Nicki Minaj',
#   'album_name': 'Pink Friday (Deluxe Edition)',
#   'album_release_date': '2010-11-22',
#   'duration_ms': 201253,
#   'popularity': 52,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202940',
#   'playlist_rank': 9,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6L0dnvrged1vonY9mlP8nd',
#   'track_name': 'Airplanes',
#   'artist_id': '5ndkK3dpZLKtBklKjxNQwT',
#   'artist_name': 'B.o.B',
#   'album_name': '2010 Bangers',
#   'album_release_date': '2024-02-22',
#   'duration_ms': 180480,
#   'popularity': 29,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202949',
#   'playlist_rank': 10,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3mX8uv98J6rCo6pzbZeG1r',
#   'track_name': 'Just the Way You Are',
#   'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'album_name': 'Invierno Musical',
#   'album_release_date': '2023-06-09',
#   'duration_ms': 220733,
#   'popularity': 27,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202958',
#   'playlist_rank': 11,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '2U8g9wVcUu9wsg6i7sFSv8',
#   'track_name': 'Every Teardrop Is a Waterfall',
#   'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'album_name': 'Every Teardrop Is a Waterfall',
#   'album_release_date': '2011-06-24',
#   'duration_ms': 243000,
#   'popularity': 27,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202966',
#   'playlist_rank': 12,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7GtiehK1LSqZysDaiaiAnp',
#   'track_name': 'Raise Your Glass',
#   'artist_id': '1KCSPY1glIKqW2TotWuXOR',
#   'artist_name': 'P!nk',
#   'album_name': 'Pop para Malhar',
#   'album_release_date': '2022-07-22',
#   'duration_ms': 202960,
#   'popularity': 25,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202975',
#   'playlist_rank': 13,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0fRfvwr9zufri1Oh7Ux8fF',
#   'track_name': 'Love You Like A Love Song',
#   'artist_id': '6dJeKm76NjfXBNTpHmOhfO',
#   'artist_name': 'Selena Gomez & The Scene',
#   'album_name': 'Love You Like A Love Song, Come & Get It, and More',
#   'album_release_date': '2021-08-20',
#   'duration_ms': 188453,
#   'popularity': 40,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202984',
#   'playlist_rank': 14,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '4u9BLz4O1VVoxXysMZgGgR',
#   'track_name': "F**kin' Perfect",
#   'artist_id': '1KCSPY1glIKqW2TotWuXOR',
#   'artist_name': 'P!nk',
#   'album_name': 'Treino Pop 2022',
#   'album_release_date': '2022-07-22',
#   'duration_ms': 213413,
#   'popularity': 27,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.202993',
#   'playlist_rank': 15,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '48qJ5q8BOdOrYQywfyoK50',
#   'track_name': 'Teenage Dream',
#   'artist_id': '6jJ0s89eD6GaHleKKya26X',
#   'artist_name': 'Katy Perry',
#   'album_name': 'Teenage Dream: The Complete Confection',
#   'album_release_date': '2012-01-01',
#   'duration_ms': 227741,
#   'popularity': 43,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203001',
#   'playlist_rank': 16,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5cYSbwNhxaHJjnXkFolc4t',
#   'track_name': "DJ Got Us Fallin' In Love (feat. Pitbull)",
#   'artist_id': '23zg3TcAtWQy7J6upgbUnj',
#   'artist_name': 'USHER',
#   'album_name': 'Ultimate Coronation Party',
#   'album_release_date': '2023-04-28',
#   'duration_ms': 221012,
#   'popularity': 27,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203010',
#   'playlist_rank': 17,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3di5hcvxxciiqwMH1jarhY',
#   'track_name': 'Set Fire to the Rain',
#   'artist_id': '4dpARuHxo51G3z768sgnrY',
#   'artist_name': 'Adele',
#   'album_name': '21',
#   'album_release_date': '2011-01-24',
#   'duration_ms': 242973,
#   'popularity': 79,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203019',
#   'playlist_rank': 18,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '36cmM3MBMWWCFIiQ90U4J8',
#   'track_name': 'Bounce (feat. Kelis) - Radio Edit',
#   'artist_id': '7CajNmpbOovFoOoasH2HaY',
#   'artist_name': 'Calvin Harris',
#   'album_name': '18 Months',
#   'album_release_date': '2012-10-29',
#   'duration_ms': 222186,
#   'popularity': 62,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203027',
#   'playlist_rank': 19,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1fBl642IhJOE5U319Gy2Go',
#   'track_name': 'Animal',
#   'artist_id': '0RpddSzUHfncUWNJXKOsjy',
#   'artist_name': 'Neon Trees',
#   'album_name': 'Habits',
#   'album_release_date': '2010-01-01',
#   'duration_ms': 212293,
#   'popularity': 28,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203036',
#   'playlist_rank': 20,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6w37LoqgjmsHSAVbFNGWC6',
#   'track_name': 'Give Me Everything',
#   'artist_id': '0TnOYISbd1XYRBk9myaseg',
#   'artist_name': 'Pitbull',
#   'album_name': "New Year's Eve 2017/18",
#   'album_release_date': '2017-12-22',
#   'duration_ms': 256133,
#   'popularity': 39,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203044',
#   'playlist_rank': 21,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7CBD8biut3IwSJDfhKHLoH',
#   'track_name': 'Adolescents',
#   'artist_id': '3YcBF2ttyueytpXtEzn1Za',
#   'artist_name': 'Incubus',
#   'album_name': 'If Not Now, When?',
#   'album_release_date': '2011-07-12',
#   'duration_ms': 288840,
#   'popularity': 47,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203053',
#   'playlist_rank': 22,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5cCAZS9VhLGEDV4NCfieeg',
#   'track_name': 'I Wanna Go',
#   'artist_id': '26dSoYclwsYLMAKD3tpOr4',
#   'artist_name': 'Britney Spears',
#   'album_name': 'Femme Fatale (Deluxe Version)',
#   'album_release_date': '2011-03-28',
#   'duration_ms': 210266,
#   'popularity': 69,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203061',
#   'playlist_rank': 23,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3G1Na74xxuAhiWLyXDPCFN',
#   'track_name': 'I Need A Doctor - Edited Version',
#   'artist_id': '6DPYiyq5kWVQS4RGwxzPC7',
#   'artist_name': 'Dr. Dre',
#   'album_name': 'I Need A Doctor',
#   'album_release_date': '2011-02-01',
#   'duration_ms': 283733,
#   'popularity': 38,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203070',
#   'playlist_rank': 24,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0tvOZuc3FCIC9mNYUvmb9q',
#   'track_name': 'Earthquake (feat. Tinie Tempah)',
#   'artist_id': '2feDdbD5araYcm6JhFHHw7',
#   'artist_name': 'Labrinth',
#   'album_name': 'Electronic Earth (Expanded Edition)',
#   'album_release_date': '2012-04-02',
#   'duration_ms': 274493,
#   'popularity': 32,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203078',
#   'playlist_rank': 25,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '2ED8sc40RVFvgqao2r3Qqn',
#   'track_name': 'Pumped Up Kicks',
#   'artist_id': '7gP3bB2nilZXLfPHJhMdvc',
#   'artist_name': 'Foster The People',
#   'album_name': "New Year's Eve - NYE 2018/2019",
#   'album_release_date': '2018-12-07',
#   'duration_ms': 239600,
#   'popularity': 40,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203087',
#   'playlist_rank': 26,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3r92pz5sSROPtUGbuCenQ2',
#   'track_name': 'Good Feeling',
#   'artist_id': '0jnsk9HBra6NMjO2oANoPY',
#   'artist_name': 'Flo Rida',
#   'album_name': '100 Uplifting Songs',
#   'album_release_date': '2021-03-26',
#   'duration_ms': 248133,
#   'popularity': 27,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203096',
#   'playlist_rank': 27,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7EuHCqVznnTfw3EGmHCztF',
#   'track_name': "Tonight (I'm F**kin' You) [feat. Ludacris & DJ Frank E]",
#   'artist_id': '6f1YthbbEpu9qHzOUW2UYI',
#   'artist_name': 'Tonight',
#   'album_name': "Tonight (I'm F**kin' You) [feat. Ludacris & DJ Frank E]",
#   'album_release_date': '2010-12-21',
#   'duration_ms': 262857,
#   'popularity': 21,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203104',
#   'playlist_rank': 28,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3uDbLzXA5iUATgCjSgP6XR',
#   'track_name': 'Novacane - Edited Version',
#   'artist_id': '2h93pZq0e7k5yf4dywlkpM',
#   'artist_name': 'Frank Ocean',
#   'album_name': 'Novacane',
#   'album_release_date': '2011-01-01',
#   'duration_ms': 302706,
#   'popularity': 45,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203113',
#   'playlist_rank': 29,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7l292gO6KcFms5gN6srppK',
#   'track_name': 'Yeah 3x',
#   'artist_id': '7bXgB6jMjp9ATFy66eO08Z',
#   'artist_name': 'Chris Brown',
#   'album_name': 'The Edge of Africa, Vol. 3',
#   'album_release_date': '2017-03-30',
#   'duration_ms': 244063,
#   'popularity': 29,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203121',
#   'playlist_rank': 30,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '2y7gde3vA56b9aRVyjxOyN',
#   'track_name': 'Feel So Close - Radio Edit',
#   'artist_id': '7CajNmpbOovFoOoasH2HaY',
#   'artist_name': 'Calvin Harris',
#   'album_name': 'Hits Internacionais Virais',
#   'album_release_date': '2022-07-22',
#   'duration_ms': 206413,
#   'popularity': 24,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203129',
#   'playlist_rank': 31,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1PVv78GWjf9EMnUHjAUzLl',
#   'track_name': "That's More Like It",
#   'artist_id': '6dJeKm76NjfXBNTpHmOhfO',
#   'artist_name': 'Selena Gomez & The Scene',
#   'album_name': 'When The Sun Goes Down',
#   'album_release_date': '2011-01-01',
#   'duration_ms': 188720,
#   'popularity': 34,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203138',
#   'playlist_rank': 32,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7DjQUa8BrQevCPtQc0YwmL',
#   'track_name': 'California Gurls',
#   'artist_id': '6jJ0s89eD6GaHleKKya26X',
#   'artist_name': 'Katy Perry',
#   'album_name': 'Teenage Dream: The Complete Confection',
#   'album_release_date': '2012-01-01',
#   'duration_ms': 234653,
#   'popularity': 33,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203147',
#   'playlist_rank': 33,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6dn9ndETOjczUSQO5UhKJa',
#   'track_name': 'Who Says',
#   'artist_id': '6dJeKm76NjfXBNTpHmOhfO',
#   'artist_name': 'Selena Gomez & The Scene',
#   'album_name': 'For You',
#   'album_release_date': '2014-11-21',
#   'duration_ms': 195266,
#   'popularity': 47,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203156',
#   'playlist_rank': 34,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7y0ucbfk5FPjNy9C9ccX0Q',
#   'track_name': 'Turn Me On',
#   'artist_id': '1Cs0zKBU1kc0i8ypK3B9ai',
#   'artist_name': 'David Guetta',
#   'album_name': 'Champions 2023',
#   'album_release_date': '2023-05-19',
#   'duration_ms': 199680,
#   'popularity': 23,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203164',
#   'playlist_rank': 35,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1LkQrnsCSpHObFdR8FJ1kD',
#   'track_name': 'Marry You',
#   'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'album_name': 'Kärlek, Lycka & Harmoni',
#   'album_release_date': '2021-07-23',
#   'duration_ms': 230120,
#   'popularity': 22,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203173',
#   'playlist_rank': 36,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '4eChY6fOCCh7rZ7hL05dxC',
#   'track_name': 'Lego House',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'album_name': 'Calm Pop Hits',
#   'album_release_date': '2022-06-17',
#   'duration_ms': 185093,
#   'popularity': 21,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203181',
#   'playlist_rank': 37,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7yIgJcn1aSgtFB13Razxvf',
#   'track_name': 'Where Have You Been',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H',
#   'artist_name': 'Rihanna',
#   'album_name': 'Talk That Talk (Deluxe)',
#   'album_release_date': '2012-07-18',
#   'duration_ms': 242680,
#   'popularity': 43,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203189',
#   'playlist_rank': 38,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6F25tznBMyPJpXx7Gj1ch0',
#   'track_name': 'The A Team',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'album_name': 'The A Team',
#   'album_release_date': '2011-12-06',
#   'duration_ms': 258373,
#   'popularity': 34,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203197',
#   'playlist_rank': 39,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '63kdURCoizshTpUcZE8U70',
#   'track_name': 'Lunar',
#   'artist_id': '1Cs0zKBU1kc0i8ypK3B9ai',
#   'artist_name': 'David Guetta',
#   'album_name': 'Nothing but the Beat - The Electronic Album',
#   'album_release_date': '2011-08-24',
#   'duration_ms': 316857,
#   'popularity': 21,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203206',
#   'playlist_rank': 40,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5EWTtSRqu7vn5f3CfAA4LQ',
#   'track_name': 'Birthday Cake',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H',
#   'artist_name': 'Rihanna',
#   'album_name': 'Twerking',
#   'album_release_date': '2019-08-02',
#   'duration_ms': 78200,
#   'popularity': 17,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203214',
#   'playlist_rank': 41,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '43hXES0j0wtL6T93yrJIGf',
#   'track_name': 'Where Them Girls At',
#   'artist_id': '1Cs0zKBU1kc0i8ypK3B9ai',
#   'artist_name': 'David Guetta',
#   'album_name': 'Summer Hits 2023',
#   'album_release_date': '2023-04-14',
#   'duration_ms': 198461,
#   'popularity': 22,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203224',
#   'playlist_rank': 42,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0jQISNPAYI5amka3mGcPJF',
#   'track_name': 'Party Rock Anthem',
#   'artist_id': '3sgFRtyBnxXD5ESfmbK4dl',
#   'artist_name': 'LMFAO',
#   'album_name': 'Throwback Hits',
#   'album_release_date': '2020-12-18',
#   'duration_ms': 264146,
#   'popularity': 26,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203233',
#   'playlist_rank': 43,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0NCNpPmEVeau2v5CoRb2sc',
#   'track_name': 'Paradise',
#   'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'album_name': 'September',
#   'album_release_date': '2020-09-04',
#   'duration_ms': 278719,
#   'popularity': 39,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203241',
#   'playlist_rank': 44,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1pYKzfOlpHWtVUiEIu4Vn7',
#   'track_name': "What's My Name?",
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H',
#   'artist_name': 'Rihanna',
#   'album_name': 'Loud',
#   'album_release_date': '2010-11-15',
#   'duration_ms': 263173,
#   'popularity': 50,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203249',
#   'playlist_rank': 45,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '4MH1fB28gWgCLrhd4GjKme',
#   'track_name': 'Sure Thing',
#   'artist_id': '360IAlyVv4PCEVjgyMZrxK',
#   'artist_name': 'Miguel',
#   'album_name': 'Viral TikTok Hits 2022 | 2023',
#   'album_release_date': '2022-12-16',
#   'duration_ms': 195028,
#   'popularity': 23,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203258',
#   'playlist_rank': 46,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5PWd45paeCuFx2KFMDwhbF',
#   'track_name': 'We R Who We R',
#   'artist_id': '6LqNN22kT3074XbTVUrhzX',
#   'artist_name': 'Kesha',
#   'album_name': 'Summer Pool Party',
#   'album_release_date': '2023-04-14',
#   'duration_ms': 204666,
#   'popularity': 21,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203266',
#   'playlist_rank': 47,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3pYDZTJM2tVBUhIRifWVzI',
#   'track_name': 'Blow',
#   'artist_id': '6LqNN22kT3074XbTVUrhzX',
#   'artist_name': 'Kesha',
#   'album_name': 'Cannibal (Expanded Edition)',
#   'album_release_date': '2010-11-19',
#   'duration_ms': 219973,
#   'popularity': 76,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203274',
#   'playlist_rank': 48,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1oBDaufG8Arkz3t52UbiQi',
#   'track_name': 'Skinny Love',
#   'artist_id': '2WX2uTcsvV5OnS0inACecP',
#   'artist_name': 'Birdy',
#   'album_name': 'Birdy',
#   'album_release_date': '2011-11-04',
#   'duration_ms': 201080,
#   'popularity': 72,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203282',
#   'playlist_rank': 49,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5rr88Jg9B0QLFMDj9qREaI',
#   'track_name': 'Louder (feat. Sian Evans)',
#   'artist_id': '6r20qOqY7qDWI0PPTxVMlC',
#   'artist_name': 'DJ Fresh',
#   'album_name': 'Louder EP',
#   'album_release_date': '2012-10-09',
#   'duration_ms': 206960,
#   'popularity': 31,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203290',
#   'playlist_rank': 50,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0PgNhIg5n0UAOBVn43b8b6',
#   'track_name': 'The Adventures of Rain Dance Maggie',
#   'artist_id': '0L8ExT028jH3ddEcZwqJJ5',
#   'artist_name': 'Red Hot Chili Peppers',
#   'album_name': "I'm with You",
#   'album_release_date': '2011-08-29',
#   'duration_ms': 282400,
#   'popularity': 69,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203299',
#   'playlist_rank': 51,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6y468DyY1V67RBNCwzrMrC',
#   'track_name': 'L.I.F.E.G.O.E.S.O.N.',
#   'artist_id': '0aeLcja6hKzb7Uz2ou7ulP',
#   'artist_name': 'Noah And The Whale',
#   'album_name': 'Last Night On Earth',
#   'album_release_date': '2011-01-01',
#   'duration_ms': 228000,
#   'popularity': 53,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203307',
#   'playlist_rank': 52,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5yzE4vbZgPGEfUegXl8Qzl',
#   'track_name': 'Donald Trump',
#   'artist_id': '4LLpKhyESsyAXpc4laK94U',
#   'artist_name': 'Mac Miller',
#   'album_name': 'Donald Trump',
#   'album_release_date': '2011-05-17',
#   'duration_ms': 165851,
#   'popularity': 18,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203316',
#   'playlist_rank': 53,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3onybpBBo6YrqIDSpfAPS5',
#   'track_name': 'Yoü And I',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'album_name': 'BORN THIS WAY THE TENTH ANNIVERSARY',
#   'album_release_date': '2021-06-25',
#   'duration_ms': 307346,
#   'popularity': 37,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203324',
#   'playlist_rank': 54,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0HZhYMZOcUzZKSFwPOti6m',
#   'track_name': 'jar of hearts',
#   'artist_id': '7H55rcKCfwqkyDFH9wpKM6',
#   'artist_name': 'Christina Perri',
#   'album_name': 'lovestrong.',
#   'album_release_date': '2011-05-10',
#   'duration_ms': 246587,
#   'popularity': 76,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203333',
#   'playlist_rank': 55,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5E6CDAxnBqc9V9Y6t5wTUE',
#   'track_name': 'Mr. Saxobeat - Radio Edit',
#   'artist_id': '0BmLNz4nSLfoWYW1cYsElL',
#   'artist_name': 'Alexandra Stan',
#   'album_name': 'Come Into My World',
#   'album_release_date': '2023-06-06',
#   'duration_ms': 195105,
#   'popularity': 36,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203341',
#   'playlist_rank': 56,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '2Adn2LNgkHMH5TelQVAu4n',
#   'track_name': 'Pretty Girl Rock',
#   'artist_id': '63wjoROpeh5f11Qm93UiJ1',
#   'artist_name': 'Keri Hilson',
#   'album_name': 'No Boys Allowed',
#   'album_release_date': '2010-01-01',
#   'duration_ms': 243920,
#   'popularity': 65,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203350',
#   'playlist_rank': 57,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7mdNKXxia7AeSuJqjjA2rb',
#   'track_name': 'Beautiful People',
#   'artist_id': '7bXgB6jMjp9ATFy66eO08Z',
#   'artist_name': 'Chris Brown',
#   'album_name': '2010s Hits',
#   'album_release_date': '2019-04-11',
#   'duration_ms': 225881,
#   'popularity': 48,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203358',
#   'playlist_rank': 58,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '4r6eNCsrZnQWJzzvFh4nlg',
#   'track_name': 'Firework',
#   'artist_id': '6jJ0s89eD6GaHleKKya26X',
#   'artist_name': 'Katy Perry',
#   'album_name': 'Best Clean Pop Hits',
#   'album_release_date': '2021-10-29',
#   'duration_ms': 227973,
#   'popularity': 19,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203366',
#   'playlist_rank': 59,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7gA5OQWsvAY7HhazroFuwI',
#   'track_name': 'Save Me, San Francisco',
#   'artist_id': '3FUY2gzHeIiaesXtOAdB7A',
#   'artist_name': 'Train',
#   'album_name': 'Save Me, San Francisco (Golden Gate Edition)',
#   'album_release_date': '2010-12-01',
#   'duration_ms': 249426,
#   'popularity': 49,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203375',
#   'playlist_rank': 60,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3KoTtGEDiBwUWzdRQVh9lh',
#   'track_name': 'Last Friday Night (T.G.I.F.)',
#   'artist_id': '6jJ0s89eD6GaHleKKya26X',
#   'artist_name': 'Katy Perry',
#   'album_name': 'Teenage Dream',
#   'album_release_date': '2010-08-24',
#   'duration_ms': 230733,
#   'popularity': 47,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203383',
#   'playlist_rank': 61,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '2tre67YRJ5bCSQ8CqYUbz0',
#   'track_name': 'The Edge Of Glory',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'album_name': 'Good Morning Music: Wake Up Workout',
#   'album_release_date': '2019-05-10',
#   'duration_ms': 320626,
#   'popularity': 23,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203391',
#   'playlist_rank': 62,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0qOnSQQF0yzuPWsXrQ9paz',
#   'track_name': 'Stereo Hearts (feat. Adam Levine)',
#   'artist_id': '4IJczjB0fJ04gs4uvP0Fli',
#   'artist_name': 'Gym Class Heroes',
#   'album_name': 'The Papercut Chronicles II',
#   'album_release_date': '2011-11-11',
#   'duration_ms': 210960,
#   'popularity': 84,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203399',
#   'playlist_rank': 63,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7w87IxuO7BDcJ3YUqCyMTT',
#   'track_name': 'Pumped Up Kicks',
#   'artist_id': '7gP3bB2nilZXLfPHJhMdvc',
#   'artist_name': 'Foster The People',
#   'album_name': 'Torches',
#   'album_release_date': '2011-05-23',
#   'duration_ms': 239600,
#   'popularity': 85,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203407',
#   'playlist_rank': 64,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7e1h7rqNB0BBC2fUuWEEFe',
#   'track_name': "Who's That Chick? (feat. Rihanna)",
#   'artist_id': '1Cs0zKBU1kc0i8ypK3B9ai',
#   'artist_name': 'David Guetta',
#   'album_name': 'One More Love',
#   'album_release_date': '2010-11-22',
#   'duration_ms': 201040,
#   'popularity': 73,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203415',
#   'playlist_rank': 65,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '4fINc8dnfcz7AdhFYVA4i7',
#   'track_name': 'It Girl',
#   'artist_id': '07YZf4WDAMNwqr4jfgOZ8y',
#   'artist_name': 'Jason Derulo',
#   'album_name': 'Future History (Deluxe Edition)',
#   'album_release_date': '2011-09-16',
#   'duration_ms': 192200,
#   'popularity': 72,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203425',
#   'playlist_rank': 66,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '2TUzU4IkfH8kcvY2MUlsd2',
#   'track_name': "I Won't Let You Go",
#   'artist_id': '3LpLGlgRS1IKPPwElnpW35',
#   'artist_name': 'James Morrison',
#   'album_name': 'The Awakening',
#   'album_release_date': '2011-01-01',
#   'duration_ms': 229303,
#   'popularity': 68,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203433',
#   'playlist_rank': 67,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '089vxHEH64AKLKhokNXEJx',
#   'track_name': 'Higher',
#   'artist_id': '6MF9fzBmfXghAz953czmBC',
#   'artist_name': 'Taio Cruz',
#   'album_name': 'Rokstarr (Special Edition)',
#   'album_release_date': '2011-01-01',
#   'duration_ms': 187666,
#   'popularity': 45,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203442',
#   'playlist_rank': 68,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '2i0AUcEnsDm3dsqLrFWUCq',
#   'track_name': 'Tonight Tonight',
#   'artist_id': '6jTnHxhb6cDCaCu4rdvsQ0',
#   'artist_name': 'Hot Chelle Rae',
#   'album_name': 'Whatever',
#   'album_release_date': '2011-11-25',
#   'duration_ms': 200466,
#   'popularity': 68,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203450',
#   'playlist_rank': 69,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5MDMFoTpN4ZIDUjNRt3AoN',
#   'track_name': 'Good Life',
#   'artist_id': '5Pwc4xIPtQLFEnJriah9YJ',
#   'artist_name': 'OneRepublic',
#   'album_name': 'Waking Up',
#   'album_release_date': '2009-11-17',
#   'duration_ms': 253080,
#   'popularity': 42,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203458',
#   'playlist_rank': 70,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0aBKFfdyOD1Ttvgv0cfjjJ',
#   'track_name': 'More - RedOne Jimmy Joker Remix',
#   'artist_id': '23zg3TcAtWQy7J6upgbUnj',
#   'artist_name': 'USHER',
#   'album_name': 'More',
#   'album_release_date': '2010-11-22',
#   'duration_ms': 219986,
#   'popularity': 71,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203466',
#   'playlist_rank': 71,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '4bCOAuhvjsxbVBM5MM8oik',
#   'track_name': 'When We Stand Together',
#   'artist_id': '6deZN1bslXzeGvOLaLMOIF',
#   'artist_name': 'Nickelback',
#   'album_name': 'Here and Now',
#   'album_release_date': '2011-11-14',
#   'duration_ms': 190786,
#   'popularity': 68,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203475',
#   'playlist_rank': 72,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3ZdJffjzJWFimSQyxgGIxN',
#   'track_name': 'Just A Dream',
#   'artist_id': '2gBjLmx6zQnFGQJCAQpRgw',
#   'artist_name': 'Nelly',
#   'album_name': '5.0',
#   'album_release_date': '2010-11-12',
#   'duration_ms': 237800,
#   'popularity': 80,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203483',
#   'playlist_rank': 73,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '4Cv5dkUBqepa0siwGREihD',
#   'track_name': 'Motivation',
#   'artist_id': '3AuMNF8rQAKOzjYppFNAoB',
#   'artist_name': 'Kelly Rowland',
#   'album_name': 'Motivation',
#   'album_release_date': '2011-01-01',
#   'duration_ms': 231173,
#   'popularity': 63,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203491',
#   'playlist_rank': 74,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1r3myKmjWoOqRip99CmSj1',
#   'track_name': "Don't Wanna Go Home",
#   'artist_id': '07YZf4WDAMNwqr4jfgOZ8y',
#   'artist_name': 'Jason Derulo',
#   'album_name': 'Future History (Deluxe Edition)',
#   'album_release_date': '2011-09-16',
#   'duration_ms': 206080,
#   'popularity': 63,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203499',
#   'playlist_rank': 75,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '2Q8e05RXzTkyiriNlW5ss5',
#   'track_name': 'Moves Like Jagger - Studio Recording From "The Voice" Performance',
#   'artist_id': '04gDigrS5kc9YWfZHwBETP',
#   'artist_name': 'Maroon 5',
#   'album_name': 'Best of 2010s',
#   'album_release_date': '2019-12-27',
#   'duration_ms': 202859,
#   'popularity': 22,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203507',
#   'playlist_rank': 76,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6S3gMF4JiXVVoavWO3VJzv',
#   'track_name': 'What Makes You Beautiful',
#   'artist_id': '4AK6F7OLvEQ5QYCBNiQWHq',
#   'artist_name': 'One Direction',
#   'album_name': 'Pop Internacional Pra Dançar 2023',
#   'album_release_date': '2023-06-12',
#   'duration_ms': 198880,
#   'popularity': 18,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203515',
#   'playlist_rank': 77,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3RuyJMim9bt3uhbAPd38xJ',
#   'track_name': 'The Show Goes On',
#   'artist_id': '01QTIT5P1pFP3QnnFSdsJf',
#   'artist_name': 'Lupe Fiasco',
#   'album_name': 'Lasers',
#   'album_release_date': '2011-03-07',
#   'duration_ms': 236666,
#   'popularity': 46,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203526',
#   'playlist_rank': 78,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '4u26EevCNXMhlvE1xFBJwX',
#   'track_name': 'If I Die Young',
#   'artist_id': '75FnCoo4FBxH5K1Rrx0k5A',
#   'artist_name': 'The Band Perry',
#   'album_name': 'The Band Perry',
#   'album_release_date': '2010-01-01',
#   'duration_ms': 222773,
#   'popularity': 68,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203534',
#   'playlist_rank': 79,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '45sDIKapDyxPl307QpEAwl',
#   'track_name': 'Rocketeer',
#   'artist_id': '698hF4vcwHwPy8ltmXermq',
#   'artist_name': 'Far East Movement',
#   'album_name': 'Free Wired',
#   'album_release_date': '2010-01-01',
#   'duration_ms': 211253,
#   'popularity': 71,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203542',
#   'playlist_rank': 80,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5e0dZqrrTaoj6AIL7VjnBM',
#   'track_name': 'Written in the Stars (feat. Eric Turner)',
#   'artist_id': '0Tob4H0FLtEONHU1MjpUEp',
#   'artist_name': 'Tinie Tempah',
#   'album_name': 'Disc-Overy',
#   'album_release_date': '2010-05-31',
#   'duration_ms': 207600,
#   'popularity': 51,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203550',
#   'playlist_rank': 81,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6HTprulGfeFVrLLvfi3t8a',
#   'track_name': 'Mr. Saxobeat - Radio Edit',
#   'artist_id': '0BmLNz4nSLfoWYW1cYsElL',
#   'artist_name': 'Alexandra Stan',
#   'album_name': 'Saxobeats',
#   'album_release_date': '2011-10-25',
#   'duration_ms': 195105,
#   'popularity': 65,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203558',
#   'playlist_rank': 82,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1f8UCzB3RqIgNkW7QIiIeP',
#   'track_name': 'Heart Skips a Beat (feat. Rizzle Kicks)',
#   'artist_id': '3whuHq0yGx60atvA2RCVRW',
#   'artist_name': 'Olly Murs',
#   'album_name': "In Case You Didn't Know",
#   'album_release_date': '2011-11-28',
#   'duration_ms': 202266,
#   'popularity': 61,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203567',
#   'playlist_rank': 83,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '5A6OHHy73AR5tLxgTc98zz',
#   'track_name': 'Black and Yellow',
#   'artist_id': '137W8MRPWKqSmrBGDBFSop',
#   'artist_name': 'Wiz Khalifa',
#   'album_name': 'Rolling Papers',
#   'album_release_date': '2011-03-29',
#   'duration_ms': 217666,
#   'popularity': 80,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203575',
#   'playlist_rank': 84,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7zbDSQelDmlaEhUDnLMViZ',
#   'track_name': 'All Of The Lights - Album Version (Edited)',
#   'artist_id': '5K4W6rqBFWDnAN6FQUkS6x',
#   'artist_name': 'Kanye West',
#   'album_name': 'My Beautiful Dark Twisted Fantasy',
#   'album_release_date': '2010-01-01',
#   'duration_ms': 299600,
#   'popularity': 53,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203583',
#   'playlist_rank': 85,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '09ZcYBGFX16X8GMDrvqQwt',
#   'track_name': 'For the First Time',
#   'artist_id': '3AQRLZ9PuTAozP28Skbq8V',
#   'artist_name': 'The Script',
#   'album_name': 'Science & Faith (US Version)',
#   'album_release_date': '2011-01-18',
#   'duration_ms': 252853,
#   'popularity': 66,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203592',
#   'playlist_rank': 86,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1NghHeg0wE32eBYrQBVQXL',
#   'track_name': 'Shake Up Christmas',
#   'artist_id': '3FUY2gzHeIiaesXtOAdB7A',
#   'artist_name': 'Train',
#   'album_name': 'Save Me, San Francisco (Golden Gate Edition)',
#   'album_release_date': '2010-12-01',
#   'duration_ms': 232213,
#   'popularity': 79,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203600',
#   'playlist_rank': 87,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0pSIJCxYqZNIZBTAnIXOkv',
#   'track_name': 'Lighters',
#   'artist_id': '77IURH5NC56Jn09QHi76is',
#   'artist_name': 'Bad Meets Evil',
#   'album_name': 'Hell: The Sequel (Deluxe)',
#   'album_release_date': '2011-01-01',
#   'duration_ms': 303813,
#   'popularity': 33,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203608',
#   'playlist_rank': 88,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '7vWFaMq63AwkFDhS2OAg5u',
#   'track_name': 'The Time (Dirty Bit)',
#   'artist_id': '1yxSLGMDHlW21z4YXirZDS',
#   'artist_name': 'Black Eyed Peas',
#   'album_name': "Class Of '11",
#   'album_release_date': '2020-04-17',
#   'duration_ms': 307640,
#   'popularity': 8,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203616',
#   'playlist_rank': 89,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '29vem0DsWK4224LQyxcmA5',
#   'track_name': 'Ai Se Eu Te Pego',
#   'artist_id': '1sDVuztNhGcetCLChkleDA',
#   'artist_name': 'Michel Teló',
#   'album_name': 'Na Balada',
#   'album_release_date': '2015-04-23',
#   'duration_ms': 165624,
#   'popularity': 0,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203624',
#   'playlist_rank': 90,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '61s24wRVyG7NP9m7EjdDKL',
#   'track_name': 'Don’t Stop The Party',
#   'artist_id': '1yxSLGMDHlW21z4YXirZDS',
#   'artist_name': 'Black Eyed Peas',
#   'album_name': 'The Beginning',
#   'album_release_date': '2010-01-01',
#   'duration_ms': 367413,
#   'popularity': 68,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203632',
#   'playlist_rank': 91,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1KEdF3FNF9bKRCxN3KUMbx',
#   'track_name': 'Friday',
#   'artist_id': '3Vl9fyKMIdLMswk8ai3mm9',
#   'artist_name': 'Rebecca Black',
#   'album_name': 'Friday',
#   'album_release_date': '2011-03-14',
#   'duration_ms': 210025,
#   'popularity': 50,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203640',
#   'playlist_rank': 92,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '3rDFqo8yv93PtTmdOYOPzX',
#   'track_name': "Tonight (I'm Fuckin' You)",
#   'artist_id': '7qG3b048QCHVRO5Pv1T5lw',
#   'artist_name': 'Enrique Iglesias',
#   'album_name': "Tonight (I'm Fuckin' You)",
#   'album_release_date': '2010-01-01',
#   'duration_ms': 231653,
#   'popularity': 48,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203648',
#   'playlist_rank': 93,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '2u02eLj96Atd6TBxkH9YvN',
#   'track_name': 'S&M',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H',
#   'artist_name': 'Rihanna',
#   'album_name': 'Loud',
#   'album_release_date': '2010-11-15',
#   'duration_ms': 243533,
#   'popularity': 56,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203657',
#   'playlist_rank': 94,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6j7hih15xG2cdYwIJnQXsq',
#   'track_name': 'Not Over You',
#   'artist_id': '5DYAABs8rkY9VhwtENoQCz',
#   'artist_name': 'Gavin DeGraw',
#   'album_name': 'Sweeter',
#   'album_release_date': '2011-09-19',
#   'duration_ms': 218520,
#   'popularity': 64,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203665',
#   'playlist_rank': 95,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0FEZedp3QtZK11jcphYQ4y',
#   'track_name': "It's Good",
#   'artist_id': '55Aa2cqylxrFIXC767Z865',
#   'artist_name': 'Lil Wayne',
#   'album_name': 'Tha Carter IV (Complete Edition)',
#   'album_release_date': '2011-08-29',
#   'duration_ms': 241466,
#   'popularity': 50,
#   'explicit': True},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203673',
#   'playlist_rank': 96,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '4c5Cd6pkg7qqzSAXjsBapX',
#   'track_name': 'How To Love',
#   'artist_id': '55Aa2cqylxrFIXC767Z865',
#   'artist_name': 'Lil Wayne',
#   'album_name': 'I Am Music',
#   'album_release_date': '2023-03-31',
#   'duration_ms': 240306,
#   'popularity': 36,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203681',
#   'playlist_rank': 97,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '0AuUL648kZtyzlMHTfw9ZT',
#   'track_name': 'Man Down',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H',
#   'artist_name': 'Rihanna',
#   'album_name': 'Loud',
#   'album_release_date': '2010-11-15',
#   'duration_ms': 267000,
#   'popularity': 46,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203689',
#   'playlist_rank': 98,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '1ExfPZEiahqhLyajhybFeS',
#   'track_name': 'The Lazy Song',
#   'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'album_name': 'Doo-Wops & Hooligans',
#   'album_release_date': '2010-05-11',
#   'duration_ms': 189109,
#   'popularity': 75,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203697',
#   'playlist_rank': 99,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '6Iocm6VMu6bVNYwiDoyQFW',
#   'track_name': 'Coming Home',
#   'artist_id': '2QYEvpsWUOjqaYuxDPTCmV',
#   'artist_name': 'Diddy - Dirty Money',
#   'album_name': 'Last Train To Paris',
#   'album_release_date': '2010-01-01',
#   'duration_ms': 238693,
#   'popularity': 67,
#   'explicit': False},
#  {'year': 2011,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:38.203705',
#   'playlist_rank': 100,
#   'playlist_name': 'Top Hits of 2011',
#   'track_id': '70Wb2xKOAOte8iNkBpezQs',
#   'track_name': 'No Hands (feat. Roscoe Dash and Wale)',
#   'artist_id': '6f4XkbvYlXMH0QgVRzW0sM',
#   'artist_name': 'Waka Flocka Flame',
#   'album_name': 'Flockaveli',
#   'album_release_date': '2010-10-01',
#   'duration_ms': 263466,
#   'popularity': 54,
#   'explicit': False},
#  {'year': 2012,
# ...
#   'playlist_rank': 99,
#   'playlist_name': 'Top Hits of 2021',
#   'track_id': '0z8hI3OPS8ADPWtoCjjLl6',
#   'track_name': 'Summer of Love (Shawn Mendes & Tainy)',
#   'artist_id': '7n2wHs1TKAczGzO7Dd2rGr',
#   'artist_name': 'Shawn Mendes',
#   'album_name': 'Summer Of Love',
#   'album_release_date': '2021-08-20',
#   'duration_ms': 184104,
#   'popularity': 68,
#   'explicit': False},
#  {'year': 2021,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:42.847435',
#   'playlist_rank': 100,
#   'playlist_name': 'Top Hits of 2021',
#   'track_id': '0eu4C55hL6x29mmeAjytzC',
#   'track_name': 'Life Goes On',
#   'artist_id': '6TLwD7HPWuiOzvXEa3oCNe',
#   'artist_name': 'Oliver Tree',
#   'album_name': 'Ugly is Beautiful: Shorter, Thicker & Uglier (Deluxe)',
#   'album_release_date': '2021-05-28',
#   'duration_ms': 161803,
#   'popularity': 74,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309600',
#   'playlist_rank': 1,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '4Dvkj6JhhA12EX05fT7y2e',
#   'track_name': 'As It Was',
#   'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'album_name': 'As It Was',
#   'album_release_date': '2022-03-31',
#   'duration_ms': 167303,
#   'popularity': 13,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309618',
#   'playlist_rank': 2,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '0V3wPSX9ygBnCm8psDIegu',
#   'track_name': 'Anti-Hero',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'album_name': 'Midnights',
#   'album_release_date': '2022-10-21',
#   'duration_ms': 200690,
#   'popularity': 81,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309628',
#   'playlist_rank': 3,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '1PtQJZVZIdWIYdARpZRDFO',
#   'track_name': 'Running Up That Hill (A Deal With God) - 2018 Remaster',
#   'artist_id': '1aSxMhuvixZ8h9dK9jIDwL',
#   'artist_name': 'Kate Bush',
#   'album_name': 'Hounds of Love (2018 Remaster)',
#   'album_release_date': '1985-09-16',
#   'duration_ms': 300840,
#   'popularity': 5,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309637',
#   'playlist_rank': 4,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '3USxtqRwSYz57Ewm6wWRMp',
#   'track_name': 'Heat Waves',
#   'artist_id': '4yvcSjfu4PC0CYQyLy4wSq',
#   'artist_name': 'Glass Animals',
#   'album_name': 'Dreamland (+ Bonus Levels)',
#   'album_release_date': '2020-08-06',
#   'duration_ms': 238805,
#   'popularity': 10,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309646',
#   'playlist_rank': 5,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '4k6Uh1HXdhtusDW5y8Gbvy',
#   'track_name': 'Bad Habit',
#   'artist_id': '57vWImR43h4CaDao012Ofp',
#   'artist_name': 'Steve Lacy',
#   'album_name': 'Gemini Rights',
#   'album_release_date': '2022-07-15',
#   'duration_ms': 232114,
#   'popularity': 84,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309656',
#   'playlist_rank': 6,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '27NovPIUIRrOZoCHxABJwK',
#   'track_name': 'INDUSTRY BABY (feat. Jack Harlow)',
#   'artist_id': '7jVv8c5Fj3E9VhNjxT4snq',
#   'artist_name': 'Lil Nas X',
#   'album_name': 'INDUSTRY BABY (feat. Jack Harlow)',
#   'album_release_date': '2021-07-23',
#   'duration_ms': 212000,
#   'popularity': 74,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309665',
#   'playlist_rank': 7,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '3nqQXoyQOWXiESFLlDF1hG',
#   'track_name': 'Unholy (feat. Kim Petras)',
#   'artist_id': '2wY79sveU1sp5g7SokKOiI',
#   'artist_name': 'Sam Smith',
#   'album_name': 'Unholy (feat. Kim Petras)',
#   'album_release_date': '2022-09-22',
#   'duration_ms': 156943,
#   'popularity': 77,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309673',
#   'playlist_rank': 8,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '1IHWl5LamUGEuP4ozKQSXZ',
#   'track_name': 'Tití Me Preguntó',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'album_name': 'Un Verano Sin Ti',
#   'album_release_date': '2022-05-06',
#   'duration_ms': 243716,
#   'popularity': 85,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309682',
#   'playlist_rank': 9,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '1xzi1Jcr7mEi9K2RfzLOqS',
#   'track_name': 'CUFF IT',
#   'artist_id': '6vWDO969PvNqNYHIOW5v0m',
#   'artist_name': 'Beyoncé',
#   'album_name': 'RENAISSANCE',
#   'album_release_date': '2022-07-29',
#   'duration_ms': 225388,
#   'popularity': 74,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309692',
#   'playlist_rank': 10,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '0VO8gYVDSwM1Qdd2GsMoYK',
#   'track_name': 'Moth To A Flame (with The Weeknd)',
#   'artist_id': '1h6Cn3P4NGzXbaXidqURXs',
#   'artist_name': 'Swedish House Mafia',
#   'album_name': 'Paradise Again',
#   'album_release_date': '2022-04-15',
#   'duration_ms': 234000,
#   'popularity': 84,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309700',
#   'playlist_rank': 11,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '2ksyzVfU0WJoBpu8otr4pz',
#   'track_name': 'METAMORPHOSIS',
#   'artist_id': '5hKGLu4Ik88FzWcTPhWNTN',
#   'artist_name': 'INTERWORLD',
#   'album_name': 'METAMORPHOSIS',
#   'album_release_date': '2021-11-25',
#   'duration_ms': 142839,
#   'popularity': 78,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309709',
#   'playlist_rank': 12,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '0wHFktze2PHC5jDt3B17DC',
#   'track_name': 'First Class',
#   'artist_id': '2LIk90788K0zvyj2JJVwkJ',
#   'artist_name': 'Jack Harlow',
#   'album_name': 'First Class',
#   'album_release_date': '2022-04-08',
#   'duration_ms': 173947,
#   'popularity': 5,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309718',
#   'playlist_rank': 13,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '1qEmFfgcLObUfQm0j1W2CK',
#   'track_name': 'Late Night Talking',
#   'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'album_name': "Harry's House",
#   'album_release_date': '2022-05-20',
#   'duration_ms': 177954,
#   'popularity': 76,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309726',
#   'playlist_rank': 14,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '5CZ40GBx1sQ9agT82CLQCT',
#   'track_name': 'traitor',
#   'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'album_name': 'SOUR',
#   'album_release_date': '2021-05-21',
#   'duration_ms': 229226,
#   'popularity': 87,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309734',
#   'playlist_rank': 15,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '6I3mqTwhRpn34SLVafSH7G',
#   'track_name': 'Ghost',
#   'artist_id': '1uNFoZAHBGtllmzznpCI3s',
#   'artist_name': 'Justin Bieber',
#   'album_name': 'Justice',
#   'album_release_date': '2021-03-19',
#   'duration_ms': 153190,
#   'popularity': 85,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309743',
#   'playlist_rank': 16,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '2mlNgAeIBnL78ZriXgrRHz',
#   'track_name': 'Glimpse of Us',
#   'artist_id': '3MZsBdqDrRTJihTHQrO6Dq',
#   'artist_name': 'Joji',
#   'album_name': 'Glimpse of Us',
#   'album_release_date': '2022-06-10',
#   'duration_ms': 233456,
#   'popularity': 8,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309751',
#   'playlist_rank': 17,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '3WMj8moIAXJhHsyLaqIIHI',
#   'track_name': 'Something in the Orange',
#   'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'artist_name': 'Zach Bryan',
#   'album_name': 'Something in the Orange',
#   'album_release_date': '2022-04-22',
#   'duration_ms': 228013,
#   'popularity': 86,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309760',
#   'playlist_rank': 18,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '0mL82sxCRjrs3br407IdJh',
#   'track_name': 'Is There Someone Else?',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'album_name': 'Dawn FM',
#   'album_release_date': '2022-01-06',
#   'duration_ms': 199111,
#   'popularity': 82,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309769',
#   'playlist_rank': 19,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '2tTmW7RDtMQtBk7m2rYeSw',
#   'track_name': 'Quevedo: Bzrp Music Sessions, Vol. 52/66',
#   'artist_id': '716NhGYqD1jl2wI1Qkgq36',
#   'artist_name': 'Bizarrap',
#   'album_name': 'Quevedo: Bzrp Music Sessions, Vol. 52/66',
#   'album_release_date': '2022-07-06',
#   'duration_ms': 198937,
#   'popularity': 81,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309778',
#   'playlist_rank': 20,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '6Sq7ltF9Qa7SNFBsV5Cogx',
#   'track_name': 'Me Porto Bonito',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'album_name': 'Un Verano Sin Ti',
#   'album_release_date': '2022-05-06',
#   'duration_ms': 178567,
#   'popularity': 83,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309786',
#   'playlist_rank': 21,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '0fX4oNGBWO3dSGUZcVdVV2',
#   'track_name': 'N95',
#   'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'album_name': 'Mr. Morale & The Big Steppers',
#   'album_release_date': '2022-05-13',
#   'duration_ms': 195950,
#   'popularity': 7,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309795',
#   'playlist_rank': 22,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '3F5CgOj3wFlRv51JsHbxhe',
#   'track_name': 'Jimmy Cooks (feat. 21 Savage)',
#   'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'album_name': 'Honestly, Nevermind',
#   'album_release_date': '2022-06-17',
#   'duration_ms': 218364,
#   'popularity': 82,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309803',
#   'playlist_rank': 23,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '6HMtHNpW6YPi1hrw9tgF8P',
#   'track_name': 'About Damn Time',
#   'artist_id': '56oDRnqbIiwx4mymNEv7dS',
#   'artist_name': 'Lizzo',
#   'album_name': 'About Damn Time',
#   'album_release_date': '2022-04-14',
#   'duration_ms': 191822,
#   'popularity': 8,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309812',
#   'playlist_rank': 24,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '5jQI2r1RdgtuT8S3iG8zFC',
#   'track_name': 'Lavender Haze',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'album_name': 'Midnights',
#   'album_release_date': '2022-10-21',
#   'duration_ms': 202395,
#   'popularity': 72,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309821',
#   'playlist_rank': 25,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '3IAfUEeaXRX9s9UdKOJrFI',
#   'track_name': 'Envolver',
#   'artist_id': '7FNnA9vBm6EKceENgCGRMb',
#   'artist_name': 'Anitta',
#   'album_name': 'Envolver',
#   'album_release_date': '2021-11-11',
#   'duration_ms': 193805,
#   'popularity': 68,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309829',
#   'playlist_rank': 26,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '5ildQOEKmJuWGl2vRkFdYc',
#   'track_name': 'DESPECHÁ',
#   'artist_id': '7ltDVBr6mKbRvohxheJ9h1',
#   'artist_name': 'ROSALÍA',
#   'album_name': 'DESPECHÁ',
#   'album_release_date': '2022-07-28',
#   'duration_ms': 157017,
#   'popularity': 73,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309838',
#   'playlist_rank': 27,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '3Kkjo3cT83cw09VJyrLNwX',
#   'track_name': 'Oh My God',
#   'artist_id': '4dpARuHxo51G3z768sgnrY',
#   'artist_name': 'Adele',
#   'album_name': '30',
#   'album_release_date': '2021-11-19',
#   'duration_ms': 225148,
#   'popularity': 74,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309847',
#   'playlist_rank': 28,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '4fouWK6XVHhzl78KzQ1UjL',
#   'track_name': 'abcdefu',
#   'artist_id': '2VSHKHBTiXWplO8lxcnUC9',
#   'artist_name': 'GAYLE',
#   'album_name': 'abcdefu',
#   'album_release_date': '2021-08-13',
#   'duration_ms': 168601,
#   'popularity': 73,
#   'explicit': True},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309855',
#   'playlist_rank': 29,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '7rglLriMNBPAyuJOMGwi39',
#   'track_name': 'Cold Heart - PNAU Remix',
#   'artist_id': '3PhoLpVuITZKcymswpck5b',
#   'artist_name': 'Elton John',
#   'album_name': 'The Lockdown Sessions',
#   'album_release_date': '2021-10-22',
#   'duration_ms': 202735,
#   'popularity': 70,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309865',
#   'playlist_rank': 30,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '50nfwKoDiSYg8zOCREWAm5',
#   'track_name': 'Shivers',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'album_name': '=',
#   'album_release_date': '2021-10-25',
#   'duration_ms': 207853,
#   'popularity': 82,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309874',
#   'playlist_rank': 31,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '0mBP9X2gPCuapvpZ7TGDk3',
#   'track_name': 'Left and Right (Feat. Jung Kook of BTS)',
#   'artist_id': '6VuMaDnrHyPL1p4EHjYLi7',
#   'artist_name': 'Charlie Puth',
#   'album_name': 'Left and Right (Feat. Jung Kook of BTS)',
#   'album_release_date': '2022-06-24',
#   'duration_ms': 154486,
#   'popularity': 68,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309882',
#   'playlist_rank': 32,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '1SOClUWhOi8vHZYMz3GluK',
#   'track_name': 'Infinity',
#   'artist_id': '6QrQ7OrISRYIfS5mtacaw2',
#   'artist_name': 'Jaymes Young',
#   'album_name': 'Feel Something',
#   'album_release_date': '2017-06-23',
#   'duration_ms': 237720,
#   'popularity': 80,
#   'explicit': False},
#  {'year': 2022,
#   'collection_date': '2025-12-27',
#   'collection_timestamp': '2025-12-27T13:45:43.309891',
#   'playlist_rank': 33,
#   'playlist_name': 'Top Hits of 2022',
#   'track_id': '0e8nrvls4Qqv5Rfa2UhqmO',
#   'track_name': 'THATS WHAT I WANT',
#   'artist_id': '7jVv8c5Fj3E9VhNjxT4snq',
#   'artist_name': 'Lil Nas X',
#   'album_name': 'MONTERO',
#   'album_release_date': '2021-09-17',
#   'duration_ms': 143901,
#   'popularity': 74,
#   'explicit': True},
#  ...]

# %%
import requests

url = "https://api.reccobeats.com/v1/audio-features?ids=3da929a8-c402-43a4-9ed3-69765d6ddf9c"

payload = {}
headers = {
  'Accept': 'application/json'
}

response = requests.request("GET", url, headers=headers, data=payload)

display(response.json()['content'])
# Out:
# [{'id': '3da929a8-c402-43a4-9ed3-69765d6ddf9c',
#   'href': 'https://open.spotify.com/track/2U8g9wVcUu9wsg6i7sFSv8',
#   'isrc': 'GBAYE1101193',
#   'acousticness': 0.00194,
#   'danceability': 0.425,
#   'energy': 0.732,
#   'instrumentalness': 0.0103,
#   'key': 9,
#   'liveness': 0.171,
#   'loudness': -6.883,
#   'mode': 1,
#   'speechiness': 0.0396,
#   'tempo': 117.98,
#   'valence': 0.333}]
