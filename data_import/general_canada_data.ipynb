# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from datetime import datetime
import os
from dotenv import load_dotenv
import json
import time

# %% [markdown]
# **II) Data Conecting**

# %%
load_dotenv()

auth_manager = SpotifyClientCredentials(
    client_id=os.getenv('SPOTIFY_CLIENT_ID'),
    client_secret=os.getenv('SPOTIFY_CLIENT_SECRET')
)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# Data extracting

# %%
def get_canada_playlist():

    playlist = {}

    results = sp.search(q = 'Top 50 Canada', type = 'playlist', market = 'CA', limit = 5)


    return playlist

# %%
playlists={}
results = sp.search(q = 'top tracks of 2025 canada', type = 'playlist', market = 'CA', limit = 30)

for playlist in results['playlists']['items']:
    if playlist != None:
        display(playlist)
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/1rEHVTPxtOjHuV0HJEu0vR'},
#  'href': 'https://api.spotify.com/v1/playlists/1rEHVTPxtOjHuV0HJEu0vR',
#  'id': '1rEHVTPxtOjHuV0HJEu0vR',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d00001e0242fe69c0e7e5c92f01ece8ceab67616d00001e025074bd0894cb1340b8d8a678ab67616d00001e02b0860cf0a98e09663c82290cab67616d00001e02cc04ff3e70e146ba9abacf40',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d00001e0242fe69c0e7e5c92f01ece8ceab67616d00001e025074bd0894cb1340b8d8a678ab67616d00001e02b0860cf0a98e09663c82290cab67616d00001e02cc04ff3e70e146ba9abacf40',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d00001e0242fe69c0e7e5c92f01ece8ceab67616d00001e025074bd0894cb1340b8d8a678ab67616d00001e02b0860cf0a98e09663c82290cab67616d00001e02cc04ff3e70e146ba9abacf40',
#    'width': 60}],
#  'name': 'Top Tracks of 2025 Canada',
#  'owner': {'display_name': 'ItsRashad',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/rry4ekspd6sxudf09xqb5we19'},
#   'href': 'https://api.spotify.com/v1/users/rry4ekspd6sxudf09xqb5we19',
#   'id': 'rry4ekspd6sxudf09xqb5we19',
#   'type': 'user',
#   'uri': 'spotify:user:rry4ekspd6sxudf09xqb5we19'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAAAmkXRmfM/R5P0GnTs6mmjeTtq3QV',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/1rEHVTPxtOjHuV0HJEu0vR/tracks',
#   'total': 50},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:1rEHVTPxtOjHuV0HJEu0vR'}
# {'collaborative': False,
#  'description': 'Best Hits 2025 | Popular Songs 2025 | Top Music Hits | Today Top Hits | Viral Hits | Radio Hits 2024/2025 | Summer Music Mix 2025 | Best Of 2025 | Summer Vibes | Deep House | Pop Vibes | Top Songs | Top Music | Global Hits | Best Songs| Clean | Pop Hits | Viral Pop - updated and active! :)',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/5KJDMJe9EJ7QRz8FG2MIpI'},
#  'href': 'https://api.spotify.com/v1/playlists/5KJDMJe9EJ7QRz8FG2MIpI',
#  'id': '5KJDMJe9EJ7QRz8FG2MIpI',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000d72cc9571da656091290878b1a3b',
#    'width': None}],
#  'name': 'BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵 ',
#  'owner': {'display_name': 'Hot Vibes',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#   'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#   'id': 'hotamazingnetwork',
#   'type': 'user',
#   'uri': 'spotify:user:hotamazingnetwork'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAArOqjIt0BjZ1o1Zw9uYsBnxn/U24xj',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/5KJDMJe9EJ7QRz8FG2MIpI/tracks',
#   'total': 147},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:5KJDMJe9EJ7QRz8FG2MIpI'}
# {'collaborative': False,
#  'description': 'The top songs in Canada today. Cover: Charli xcx',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/68RlYL4IIEfNGZ5BPUaJjF'},
#  'href': 'https://api.spotify.com/v1/playlists/68RlYL4IIEfNGZ5BPUaJjF',
#  'id': '68RlYL4IIEfNGZ5BPUaJjF',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-fa.spotifycdn.com/image/ab67706c0000da8449d71ca666d9b1d0b8728db8',
#    'width': None}],
#  'name': 'TOP 100 HITS 2025',
#  'owner': {'display_name': 'Topsify Canada',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/playlistmecanada'},
#   'href': 'https://api.spotify.com/v1/users/playlistmecanada',
#   'id': 'playlistmecanada',
#   'type': 'user',
#   'uri': 'spotify:user:playlistmecanada'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAx2hBrKd1lC67xdb3YdKmGpGoKzQw5',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/68RlYL4IIEfNGZ5BPUaJjF/tracks',
#   'total': 101},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:68RlYL4IIEfNGZ5BPUaJjF'}
# {'collaborative': False,
#  'description': 'Canadian top hits from Billboard Canada Top 100 - Canada Hits - Canadian Hits - Canadian Charts - Top Hits Canada - Radio Hits Canada - Charts Canada. Updated weekly!',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/3K8gXth4PNi1LiKorln41i'},
#  'href': 'https://api.spotify.com/v1/playlists/3K8gXth4PNi1LiKorln41i',
#  'id': '3K8gXth4PNi1LiKorln41i',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da848dfa893e2adfcff8d3ec01a6',
#    'width': None}],
#  'name': 'Canada Top 100 2025',
#  'owner': {'display_name': 'Soave',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/21ifzjxggdajdpc4w6iqxslkq'},
#   'href': 'https://api.spotify.com/v1/users/21ifzjxggdajdpc4w6iqxslkq',
#   'id': '21ifzjxggdajdpc4w6iqxslkq',
#   'type': 'user',
#   'uri': 'spotify:user:21ifzjxggdajdpc4w6iqxslkq'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAALHS1weFVuKlW+UZmqtiW3QmCkaRMo',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/3K8gXth4PNi1LiKorln41i/tracks',
#   'total': 100},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:3K8gXth4PNi1LiKorln41i'}
# {'collaborative': False,
#  'description': 'Best Pop Hits',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/34NbomaTu7YuOYnky8nLXL'},
#  'href': 'https://api.spotify.com/v1/playlists/34NbomaTu7YuOYnky8nLXL',
#  'id': '34NbomaTu7YuOYnky8nLXL',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d00001e027e0698e1398b6473de43f901ab67616d00001e0282ea2e9e1858aa012c57cd45ab67616d00001e029a336bfb6d40bbd90a507417ab67616d00001e02fa2bcf3df669bde08b2e7d36',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d00001e027e0698e1398b6473de43f901ab67616d00001e0282ea2e9e1858aa012c57cd45ab67616d00001e029a336bfb6d40bbd90a507417ab67616d00001e02fa2bcf3df669bde08b2e7d36',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d00001e027e0698e1398b6473de43f901ab67616d00001e0282ea2e9e1858aa012c57cd45ab67616d00001e029a336bfb6d40bbd90a507417ab67616d00001e02fa2bcf3df669bde08b2e7d36',
#    'width': 60}],
#  'name': 'Pop Hits 2025 (Top 50)',
#  'owner': {'display_name': 'TylerLife',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#   'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#   'id': '313odiyd72vqxinsh4grr4wqqfpa',
#   'type': 'user',
#   'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAABAfGlurpu5zi4bSHqq91oh+b9b5i1',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/34NbomaTu7YuOYnky8nLXL/tracks',
#   'total': 56},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:34NbomaTu7YuOYnky8nLXL'}
# {'collaborative': False,
#  'description': "HITS 2025 / 2026 🔥 All of today's top chart hits and hot new releases from around the world. Hit ♡ to hear the biggest new songs first! Cover: Sombr",
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/5iwkYfnHAGMEFLiHFFGnP4'},
#  'href': 'https://api.spotify.com/v1/playlists/5iwkYfnHAGMEFLiHFFGnP4',
#  'id': '5iwkYfnHAGMEFLiHFFGnP4',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000d72c4e47b0df701c463d80f96c39',
#    'width': None}],
#  'name': "HITS 2025 - Today's Top Songs",
#  'owner': {'display_name': 'Topsify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/topsify'},
#   'href': 'https://api.spotify.com/v1/users/topsify',
#   'id': 'topsify',
#   'type': 'user',
#   'uri': 'spotify:user:topsify'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAad9UoD3Mwz9lULsUNlv6wszEfMrUb',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/5iwkYfnHAGMEFLiHFFGnP4/tracks',
#   'total': 60},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:5iwkYfnHAGMEFLiHFFGnP4'}
# {'collaborative': False,
#  'description': 'Plug into the heartbeat of modern Punjabi music.  This playlist features top trending tracks and recent releases from chart-busting icons (AP Dhillon, Sukha, Cheema Y, Prem Dhillon) and Punjabi tradition with global sounds | cover: AP Dhillon | Ig: wavemusicpro',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/6yny06kx0NkUdZ8t6U9bia'},
#  'href': 'https://api.spotify.com/v1/playlists/6yny06kx0NkUdZ8t6U9bia',
#  'id': '6yny06kx0NkUdZ8t6U9bia',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000d72cc88c0c4b9345bc74ae36400b',
#    'width': None}],
#  'name': 'Canada’s Punjabi Wave 2025: AP Dhillon, Sukha, Cheema Y, Prem Dhillon & New Horizons',
#  'owner': {'display_name': 'Wave Music Co.',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/31ak2xhqpt4rkklhn5bttcn236hu'},
#   'href': 'https://api.spotify.com/v1/users/31ak2xhqpt4rkklhn5bttcn236hu',
#   'id': '31ak2xhqpt4rkklhn5bttcn236hu',
#   'type': 'user',
#   'uri': 'spotify:user:31ak2xhqpt4rkklhn5bttcn236hu'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAACofrxcDDUIJjIpMFyJ1qXZWVSFIL0',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/6yny06kx0NkUdZ8t6U9bia/tracks',
#   'total': 13},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:6yny06kx0NkUdZ8t6U9bia'}
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/3Pft9VkD2PXIK9EPOlVo9Z'},
#  'href': 'https://api.spotify.com/v1/playlists/3Pft9VkD2PXIK9EPOlVo9Z',
#  'id': '3Pft9VkD2PXIK9EPOlVo9Z',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84876eb99d2d5645b7dc538400',
#    'width': None}],
#  'name': 'HITSTER - Canada',
#  'owner': {'display_name': 'HITSTER',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/ta8hnikdhdctwuvkj2nl9itix'},
#   'href': 'https://api.spotify.com/v1/users/ta8hnikdhdctwuvkj2nl9itix',
#   'id': 'ta8hnikdhdctwuvkj2nl9itix',
#   'type': 'user',
#   'uri': 'spotify:user:ta8hnikdhdctwuvkj2nl9itix'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAABMTs/oSz7wInlO4T64xbRjrGYvFx',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/3Pft9VkD2PXIK9EPOlVo9Z/tracks',
#   'total': 308},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:3Pft9VkD2PXIK9EPOlVo9Z'}
# {'collaborative': False,
#  'description': 'The greatest Canadian songs to have existed throughout time. Mix of all genres. Cover Picture: Bryan Adams ',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/2hzDwOSCuQxQxFAiyyQJbL'},
#  'href': 'https://api.spotify.com/v1/playlists/2hzDwOSCuQxQxFAiyyQJbL',
#  'id': '2hzDwOSCuQxQxFAiyyQJbL',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84a4d56a841581983f12c1247a',
#    'width': None}],
#  'name': 'Best Canadian Hits: Top 100 ',
#  'owner': {'display_name': 'gorman.shawn23',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/gorman.shawn23'},
#   'href': 'https://api.spotify.com/v1/users/gorman.shawn23',
#   'id': 'gorman.shawn23',
#   'type': 'user',
#   'uri': 'spotify:user:gorman.shawn23'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAAZjpLh4ACy65utyUGs0PT8aLhnup2',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/2hzDwOSCuQxQxFAiyyQJbL/tracks',
#   'total': 73},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:2hzDwOSCuQxQxFAiyyQJbL'}
# {'collaborative': False,
#  'description': 'if you grew up in canada, you probably know all of these songs 🇨🇦🍁 ty for listening &lt;3',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/1igAhGShFCUwmKikegeR1F'},
#  'href': 'https://api.spotify.com/v1/playlists/1igAhGShFCUwmKikegeR1F',
#  'id': '1igAhGShFCUwmKikegeR1F',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000d72c236efe7c0cc27d804d37aabf',
#    'width': None}],
#  'name': 'canadian radio hits from early 2000s',
#  'owner': {'display_name': 'kyliebester',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/kyliebester'},
#   'href': 'https://api.spotify.com/v1/users/kyliebester',
#   'id': 'kyliebester',
#   'type': 'user',
#   'uri': 'spotify:user:kyliebester'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAA/4ii2eE/pAxenmIpMil2VvKXS/ew',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/1igAhGShFCUwmKikegeR1F/tracks',
#   'total': 241},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:1igAhGShFCUwmKikegeR1F'}
# {'collaborative': False,
#  'description': 'Discover homegrown Canadian Christmas talent here singing all of your festive favs! | Christmas in Canada | Holiday music | Christmas playlist | Christmas carols | Festive music | Christmas hits | Christmas music 2025 | Christmas vibes | Xmas hits | Christmas classics | Canadian Christmas | Mariah',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/7sSWqYac1cV8fARoHmcMzQ'},
#  'href': 'https://api.spotify.com/v1/playlists/7sSWqYac1cV8fARoHmcMzQ',
#  'id': '7sSWqYac1cV8fARoHmcMzQ',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84cbf7cd700690b49eb18d989f',
#    'width': None}],
#  'name': 'Christmas in Canada',
#  'owner': {'display_name': 'Filtr Canada\t',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/filtr.ca'},
#   'href': 'https://api.spotify.com/v1/users/filtr.ca',
#   'id': 'filtr.ca',
#   'type': 'user',
#   'uri': 'spotify:user:filtr.ca'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAA00Yl45S6eSZJjg+5isZ6UDt+C+BC',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/7sSWqYac1cV8fARoHmcMzQ/tracks',
#   'total': 70},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:7sSWqYac1cV8fARoHmcMzQ'}
# {'collaborative': False,
#  'description': 'Label: Quality Music - Series: Dance Mix, Dance Mix (MuchMusic) – 1995 - Country: Canada - Released: Aug 1, 1995 - Genre: #Electronic, #Pop - Style: #Eurodance, #House, #EuroHouse, #Latin',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/7EDVMqXEEu5kvKYpcXgDax'},
#  'href': 'https://api.spotify.com/v1/playlists/7EDVMqXEEu5kvKYpcXgDax',
#  'id': '7EDVMqXEEu5kvKYpcXgDax',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-fa.spotifycdn.com/image/ab67706c0000d72c0f23e8b9fb4a4d80c62602c3',
#    'width': None}],
#  'name': 'Dance Mix ‘95',
#  'owner': {'display_name': 'ren17pen',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/5ogvz4vwb1bvrqruq6sr7iqnx'},
#   'href': 'https://api.spotify.com/v1/users/5ogvz4vwb1bvrqruq6sr7iqnx',
#   'id': '5ogvz4vwb1bvrqruq6sr7iqnx',
#   'type': 'user',
#   'uri': 'spotify:user:5ogvz4vwb1bvrqruq6sr7iqnx'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAAH4E0s/0LTS7T/mJMZ4xOpor3+kWY',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/7EDVMqXEEu5kvKYpcXgDax/tracks',
#   'total': 17},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:7EDVMqXEEu5kvKYpcXgDax'}
